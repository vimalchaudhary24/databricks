# %%
df = spark.read.format("excel") \
    .option("header", "True") \
    .option("inferSchema", "true") \
    .load("s3://s3-databrick-final/statement_excel_latest.xlsx")

# %%
df.display()

# %%
df.write.format("delta") \
    .mode("overwrite") \
    .option("path", "s3://s3-databrick-final/src/") \
    .saveAsTable("edl_dev.databricks_ci_cd_src.account_statement_2026")
