# %%
df = spark.read.format("com.crealytics.spark.excel") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Workspace/Users/vimalchaudhary24@gmail.com/statement_excel.xlsx")

display(df)
